# %% [markdown]
# <a href="https://colab.research.google.com/github/9characters/2D-Poster_injection/blob/master/Colab_2_TensorFlow_2_0_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TensorFlow 1.X

# %% [markdown]
# ### Installing TensorFlow 1.X

# %%
#!pip install tensorflow-gpu

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.2'

# %% [markdown]
# ### Constants

# %% [markdown]
# #### Defining a constant

# %%
# Defining a TensorFlow constant
tensor = tf.constant([[26, 81], [45, 75]])

# %%
tensor
# Out:
# <tf.Tensor 'Const:0' shape=(2, 2) dtype=int32>

# %%
# If a session is not initialized, we cannot access the values of the constant
tensor.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-85663888a91e> in <module>()
#       1 # If a session is not initialized, we cannot access the values of the constant
# ----> 2 tensor.eval()
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in eval(self, feed_dict, session)
#     796
#     797     """
# --> 798     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     799
#     800   def experimental_ref(self):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5391     session = get_default_session()
#    5392     if session is None:
# -> 5393       raise ValueError("Cannot evaluate tensor using `eval()`: No default "
#    5394                        "session is registered. Use `with "
#    5395                        "sess.as_default()` or pass an explicit session to "
#
# ValueError: Cannot evaluate tensor using `eval()`: No default session is registered. Use `with sess.as_default()` or pass an explicit session to `eval(session=sess)`

# %% [markdown]
# #### Getting the values of a constant

# %%
session = tf.Session()

# %%
session.run(tf.global_variables_initializer())

# %%
tensor_value = session.run(tensor)

# %%
tensor_value
# Out:
# array([[26, 81],
#        [45, 75]], dtype=int32)

# %% [markdown]
# ### Variables

# %% [markdown]
# #### Defining a variable

# %%
variable = tf.Variable([[26, 81], [45, 75]])

# %%
variable
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32_ref>

# %%
variable.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-37927263c520> in <module>()
# ----> 1 variable.eval()
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/variables.py in eval(self, session)
#    2022       A numpy `ndarray` with a copy of the value of this variable.
#    2023     """
# -> 2024     return self._variable.eval(session=session)
#    2025
#    2026   @property
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in eval(self, feed_dict, session)
#     796
#     797     """
# --> 798     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     799
#     800   def experimental_ref(self):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5391     session = get_default_session()
#    5392     if session is None:
# -> 5393       raise ValueError("Cannot evaluate tensor using `eval()`: No default "
#    5394                        "session is registered. Use `with "
#    5395                        "sess.as_default()` or pass an explicit session to "
#
# ValueError: Cannot evaluate tensor using `eval()`: No default session is registered. Use `with sess.as_default()` or pass an explicit session to `eval(session=sess)`

# %% [markdown]
# #### Getting the values of a variable

# %%
# Initializing a session
session = tf.Session()

# %%
# Initializing ALL the variables from the session
session.run(tf.global_variables_initializer())

# %%
# Running the eval method on the environment with the initialized session to retrieve values from it
variable.eval(session)
# Out:
# array([[26, 81],
#        [45, 75]], dtype=int32)

# %% [markdown]
# ## TensorFlow 2.0

# %% [markdown]
# ### Installing TensorFlow 2.0

# %%
#!pip install tensorflow-gpu==2.0.0-alpha0

# %%
import tensorflow as tf
import numpy as np

# %%
tf.__version__
# Out:
# '2.6.0'

# %% [markdown]
# ### Constants

# %% [markdown]
# #### Defining a constant

# %%
# Defining a constant in TensorFlow 2.0
tensor_20 = tf.constant([[23, 4], [32, 51]])

# %%
tensor_20
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
# Getting the shape of a tensor
tensor_20.shape
# Out:
# TensorShape([2, 2])

# %% [markdown]
# #### Getting the values of a constant

# %%
# Getting the values straight from a TensorFlow constant with numpy, and without the need of a session
tensor_20.numpy()
# Out:
# array([[23,  4],
#        [32, 51]], dtype=int32)

# %%
# We are able to convert a numpy array back to a TensorFlow tensor as well
numpy_tensor = np.array([[26, 81], [45, 75]])

# %%
tensor_from_numpy = tf.constant(numpy_tensor)

# %%
tensor_from_numpy
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[26, 81],
#        [45, 75]])>

# %% [markdown]
# ### Variables

# %% [markdown]
# #### Defining a variable

# %%
tf2_variable = tf.Variable([[26, 81], [45, 75], [44, 67]])
tf2_variable
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[26, 81],
#        [45, 75],
#        [44, 67]], dtype=int32)>

# %% [markdown]
# #### Getting the values of a variable

# %%
tf2_variable.numpy()
# Out:
# array([[26, 81],
#        [45, 75],
#        [44, 67]], dtype=int32)

# %% [markdown]
# #### Changing a specific value in the variable

# %%
tf2_variable[2,1].assign(68)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 2) dtype=int32, numpy=
# array([[26, 81],
#        [45, 75],
#        [44, 68]], dtype=int32)>

# %%
tf2_variable
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[26, 81],
#        [45, 75],
#        [44, 68]], dtype=int32)>

# %% [markdown]
# ### Operations with tensors

# %%
tensor = tf.constant([[26,81], [45,75]])

# %% [markdown]
# #### Addition between a scalar and a tensor

# %%
tensor + 2
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[28, 83],
#        [47, 77]], dtype=int32)>

# %% [markdown]
# #### Multiplication between a scalar and a tensor

# %%
tensor * 5
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[130, 405],
#        [225, 375]], dtype=int32)>

# %% [markdown]
# #### Using Numpy functions on TensorFlow tensors

# %%
np.square(tensor)
# Out:
# numpy.ndarray

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[26, 81],
#        [45, 75]], dtype=int32)>

# %%
print(type(tensor))
# Out:
# <class 'numpy.ndarray'>

# %%
# Getting the squares of all numbers in a TensorFlow tensor object
np.square(tensor)
# Out:
# array([[ 1,  4],
#        [ 9, 16]], dtype=int32)

# %%
# Getting the square root of all numbers in a tensorflow tensor object
np.sqrt(tensor)
# Out:
# array([[5.09901951, 9.        ],
#        [6.70820393, 8.66025404]])

# %% [markdown]
# #### Dot product between two tensors

# %%
tensor = tf.constant([[2,3], [4,5]])

# %%
tensor * tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 4,  9],
#        [16, 25]], dtype=int32)>

# %%
np.dot(tensor, tensor)
# Out:
# array([[16, 21],
#        [28, 37]], dtype=int32)

# %% [markdown]
# ### Strings in TensorFlow 2.0

# %%
tf_string = tf.constant("Hello There")

# %%
tf_string
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'Hello There'>

# %%
print(tf.strings.length(tf_string))
# Out:
# tf.Tensor(11, shape=(), dtype=int32)

# %%
tf_string = tf.constant("TensorFlow")
tf_string
# Out:
# <tf.Tensor: id=62, shape=(), dtype=string, numpy=b'TensorFlow'>

# %% [markdown]
# #### Simple string operations

# %%
tf.strings.length(tf_string)
# Out:
# <tf.Tensor: id=49, shape=(), dtype=int32, numpy=10>

# %%
string = tf.constant("abcdef")

# %%
tf.strings.unicode_decode(string, "ASCII")
# Out:
# <tf.Tensor: shape=(6,), dtype=int32, numpy=array([ 97,  98,  99, 100, 101, 102], dtype=int32)>

# %%
tf.strings.unicode_decode(tf_string, "UTF8")
# Out:
# <tf.Tensor: id=58, shape=(10,), dtype=int32, numpy=array([ 84, 101, 110, 115, 111, 114,  70, 108, 111, 119], dtype=int32)>

# %% [markdown]
# #### Storing arrays of strings

# %%
tf_string_array = tf.constant(["TensorFlow", "Deep Learning", "AI"])

# %%
# Iterating through the TF string array
for string in tf_string_array:
  print(string)
# Out:
# tf.Tensor(b'TensorFlow', shape=(), dtype=string)
# tf.Tensor(b'Deep Learning', shape=(), dtype=string)
# tf.Tensor(b'AI', shape=(), dtype=string)
